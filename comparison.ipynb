# %%
import pandas as pd

# Replace 'file1.csv' and 'file2.csv' with the paths to your CSV files
file1_path = 'New_query_2024_05_26.csv'
file2_path = 'drmax.csv'

# Reading the CSV files into dataframes
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)

# Now df1 and df2 contain the data from your CSV files

# %%
# Extracting the 'prod_key' column from each dataframe
prod_key_df1 = set(df1['prod_key'])
prod_key_df2 = set(df2['prod_key'])

# Finding prod_keys present only in one dataframe but not in the other
prod_key_only_in_df1 = prod_key_df1 - prod_key_df2
prod_key_only_in_df2 = prod_key_df2 - prod_key_df1

# Printing the results
print("prod_keys only in df1(ada):", prod_key_only_in_df1)
print("prod_keys only in df2(drmax):", prod_key_only_in_df2)
# Out:
# prod_keys only in df1(ada): set()
# prod_keys only in df2(drmax): {7509276, 7500135}

# %%
# Merge the dataframes on 'prod_key' column
merged_df = pd.merge(df1, df2, on='prod_key', how='inner', suffixes=('_ada', '_drmax'))
merged_df = merged_df.round(2)

# If you want to include prod_keys that are only in one dataframe, you can use 'outer' instead of 'inner'
# merged_df = pd.merge(df1, df2, on='prod_key', how='outer',suffixes=('_ada', '_drmax'))
# merged_df = merged_df.round(2)

# Display the merged dataframe
merged_df.head()
# Out:
#    prod_key  qty_ada  local_acg_ada  local_disc_ada  qty_drmax  \
# 0   1048582   136.71        4323.06         3948.58     136.71
# 1   1048616    29.00         150.10          150.10      29.00
# 2   1048672   171.66        4261.26         4019.20     171.67
# 3   1048673    14.50         365.10          332.85      14.50
# 4   1048674   170.00        4518.40         4248.52     170.00
#
#    local_acg_drmax  local_disc_drmax
# 0          3966.33           3824.15
# 1           126.15            126.15
# 2          3909.62           3687.48
# 3           334.95            305.37
# 4          4145.25           4081.90

# %%
# # Create new columns to indicate differences
merged_df['qty_diff'] = (merged_df['qty_ada'] != merged_df['qty_drmax'])
merged_df['local_acg_diff'] = (merged_df['local_acg_ada'] != merged_df['local_acg_drmax'])
merged_df['local_disc_diff'] = (merged_df['local_disc_ada'] != merged_df['local_disc_drmax'])

# Display the updated dataframe
merged_df.head()


# Calculate the differences and store them in new columns
merged_df['qty_diff_val'] = (merged_df['qty_ada'] - merged_df['qty_drmax']).round(2)
merged_df['local_acg_diff_val'] = (merged_df['local_acg_ada'] - merged_df['local_acg_drmax']).round(2)
merged_df['local_disc_diff_val'] = (merged_df['local_disc_ada'] - merged_df['local_disc_drmax']).round(2)

# Display the updated dataframez
merged_df.head()
# Out:
#    prod_key  qty_ada  local_acg_ada  local_disc_ada  qty_drmax  \
# 0   1048582   136.71        4323.06         3948.58     136.71
# 1   1048616    29.00         150.10          150.10      29.00
# 2   1048672   171.66        4261.26         4019.20     171.67
# 3   1048673    14.50         365.10          332.85      14.50
# 4   1048674   170.00        4518.40         4248.52     170.00
#
#    local_acg_drmax  local_disc_drmax  qty_diff  local_acg_diff  \
# 0          3966.33           3824.15     False            True
# 1           126.15            126.15     False            True
# 2          3909.62           3687.48      True            True
# 3           334.95            305.37     False            True
# 4          4145.25           4081.90     False            True
#
#    local_disc_diff  qty_diff_val  local_acg_diff_val  local_disc_diff_val
# 0             True          0.00              356.73               124.43
# 1             True          0.00               23.95                23.95
# 2             True         -0.01              351.64               331.72
# 3             True          0.00               30.15                27.48
# 4             True          0.00              373.15               166.62

# %%
column_sums = merged_df.sum().round(2)


# Display the sums
print(column_sums)
# Out:
# prod_key               5.940595e+11
# qty_ada                6.786338e+05
# local_acg_ada          1.625317e+07
# local_disc_ada         1.422086e+07
# qty_drmax              6.786334e+05
# local_acg_drmax        1.445360e+07
# local_disc_drmax       1.291227e+07
# qty_diff               2.060000e+02
# local_acg_diff         3.539000e+03
# local_disc_diff        3.358000e+03
# qty_diff_val           3.800000e-01
# local_acg_diff_val     1.799572e+06
# local_disc_diff_val    1.308589e+06
# dtype: float64
